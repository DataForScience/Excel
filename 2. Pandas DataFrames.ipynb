# %% [markdown]
# <div style="width: 100%; overflow: hidden;">
#     <div style="width: 150px; float: left;"> <img src="data/D4Sci_logo_ball.png" alt="Data For Science, Inc" align="left" border="0"> </div>
#     <div style="float: left; margin-left: 10px;"> <h1>Transforming Excel Analysis into pandas Data Models</h1>
# <h1>Pandas DataFrames</h1>
#         <p>Bruno Gonçalves<br/>
#         <a href="http://www.data4sci.com/">www.data4sci.com</a><br/>
#             @bgoncalves, @data4sci</p></div>
# </div>

# %%
import matplotlib
import matplotlib.pyplot as plt

import pandas as pd
import numpy as np

import watermark

# %load_ext watermark
# %matplotlib inline

# %% [markdown]
# We start by print out the versions of the libraries we're using for future reference

# %%
# %watermark -n -v -m -g -iv
# Out:
# watermark  2.0.2
# json       2.0.9
# autopep8   1.5
# numpy      1.18.1
# pandas     1.0.1
# matplotlib 3.1.3
# Thu Sep 03 2020
#
# CPython 3.7.3
# IPython 6.2.1
#
# compiler   : Clang 4.0.1 (tags/RELEASE_401/final)
# system     : Darwin
# release    : 19.6.0
# machine    : x86_64
# processor  : i386
# CPU cores  : 8
# interpreter: 64bit
# Git hash   : 645675cceecd8c43030193fc309fa409552f669e

# %% [markdown]
# Set the default figure style

# %%
plt.style.use('./d4sci.mplstyle')

# %% [markdown]
# ## DataFrames and Series

# %% [markdown]
# Series and DataFrames can be thought of as dictionaries associating keys to lists of values

# %%
data = {"id": [23, 42, 12, 86], "Name": ["Bob", "Karen", "Kate", "Bill"]}

# %%
data
# Out:
# {'Name': ['Bob', 'Karen', 'Kate', 'Bill'], 'id': [23, 42, 12, 86]}

# %% [markdown]
# A Series corresponds to just a sigle list of values

# %%
series = pd.Series(data["id"])

# %%
series
# Out:
# 0    23
# 1    42
# 2    12
# 3    86
# dtype: int64

# %% [markdown]
# While a DataFrame can have multiple

# %%
 df = pd.DataFrame(data)

# %%
df
# Out:
#    id   Name
# 0  23    Bob
# 1  42  Karen
# 2  12   Kate
# 3  86   Bill

# %% [markdown]
# Another way of looking at it, is that DataFrames are essentially groups of individual Series. Each Series can have it's own datatype **dtype**

# %%
df.dtypes
# Out:
# id       int64
# Name    object
# dtype: object

# %% [markdown]
# We can get general information about how the DataFrame is being stored by calling __info()__

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      4 non-null      int64
#  1   Name    4 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 192.0+ bytes

# %% [markdown]
# Subsetting a DataFrame by column name we retrieve the underlying Series

# %%
type(df['id'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# Both columns and index values have types and possibly names

# %%
df.columns
# Out:
# Index(['id', 'Name'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %% [markdown]
# And we can query the shape and number of dimensions of the DataFrame easily

# %%
df.shape
# Out:
# (4, 2)

# %%
df.ndim
# Out:
# 2

# %% [markdown]
# And relabel both index and column values

# %%
df.index = ["row" + str(i) for i in range(4)]
df.columns = ['ID', 'First Name']

# %%
df.loc['row1']
# Out:
# ID               42
# First Name    Karen
# Name: row1, dtype: object

# %%
df.iloc[1]
# Out:
# ID               42
# First Name    Karen
# Name: row1, dtype: object

# %% [markdown]
# ## Importing and exporting data

# %% [markdown]
# ### Read csv files

# %% [markdown]
# File can be zipped

# %%
green = pd.read_csv('data/green_tripdata_2014-04.csv.gz', 
        parse_dates=['lpep_pickup_datetime', 'Lpep_dropoff_datetime'], nrows=1000, index_col='VendorID', 
        dtype={'RateCodeID':'str', 'Trip_type': 'str'}
                   )

# %% [markdown]
# We read only 1000 rows as expected

# %%
green.shape
# Out:
# (1000, 21)

# %% [markdown]
# And used the right dtypes for each column

# %%
green.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 2 to 2
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   lpep_pickup_datetime   1000 non-null   datetime64[ns]
#  1   Lpep_dropoff_datetime  1000 non-null   datetime64[ns]
#  2   Store_and_fwd_flag     1000 non-null   object
#  3   RateCodeID             1000 non-null   object
#  4   Pickup_longitude       1000 non-null   float64
#  5   Pickup_latitude        1000 non-null   float64
#  6   Dropoff_longitude      1000 non-null   float64
#  7   Dropoff_latitude       1000 non-null   float64
#  8   Passenger_count        1000 non-null   int64
#  9   Trip_distance          1000 non-null   float64
#  10  Fare_amount            1000 non-null   float64
#  11  Extra                  1000 non-null   float64
#  12  MTA_tax                1000 non-null   float64
#  13  Tip_amount             1000 non-null   float64
#  14  Tolls_amount           1000 non-null   float64
#  15  Ehail_fee              0 non-null      float64
#  16  Total_amount           1000 non-null   float64
#  17  Payment_type           1000 non-null   int64
#  18  Trip_type              788 non-null    object
#  19  Unnamed: 20            0 non-null      float64
#  20                         0 non-null      float64
# dtypes: datetime64[ns](2), float64(14), int64(2), object(3)
# memory usage: 171.9+ KB

# %% [markdown]
# ### Read excel spreadsheets

# %% [markdown]
# By default, __read_excel__ reads the first spreadsheet

# %%
movies = pd.read_excel('data/movies.xlsx', index_col='Title')

# %%
movies.head()
# Out:
#                                                    Year               Genres  \
# Title
# Intolerance: Love's Struggle Throughout the Ages   1916    Drama|History|War
# Over the Hill to the Poorhouse                     1920          Crime|Drama
# The Big Parade                                     1925    Drama|Romance|War
# Metropolis                                         1927         Drama|Sci-Fi
# Pandora's Box                                      1929  Crime|Drama|Romance
#
#                                                   Language  Country  \
# Title
# Intolerance: Love's Struggle Throughout the Ages       NaN      USA
# Over the Hill to the Poorhouse                         NaN      USA
# The Big Parade                                         NaN      USA
# Metropolis                                          German  Germany
# Pandora's Box                                       German  Germany
#
#                                                   Content Rating  Duration  \
# Title
# Intolerance: Love's Struggle Throughout the Ages       Not Rated       123
# Over the Hill to the Poorhouse                               NaN       110
# The Big Parade                                         Not Rated       151
# Metropolis                                             Not Rated       145
# Pandora's Box                                          Not Rated       110
#
#                                                    Aspect Ratio     Budget  \
# Title
# Intolerance: Love's Struggle Throughout the Ages           1.33   385907.0
# Over the Hill to the Poorhouse                             1.33   100000.0
# The Big Parade                                             1.33   245000.0
# Metropolis                                                 1.33  6000000.0
# Pandora's Box                                              1.33        NaN
#
#                                                    Gross Earnings  \
# Title
# Intolerance: Love's Struggle Throughout the Ages              NaN
# Over the Hill to the Poorhouse                          3000000.0
# The Big Parade                                                NaN
# Metropolis                                                26435.0
# Pandora's Box                                              9950.0
#
#                                                               Director  ...  \
# Title                                                                   ...
# Intolerance: Love's Struggle Throughout the Ages         D.W. Griffith  ...
# Over the Hill to the Poorhouse                       Harry F. Millarde  ...
# The Big Parade                                              King Vidor  ...
# Metropolis                                                  Fritz Lang  ...
# Pandora's Box                                      Georg Wilhelm Pabst  ...
#
#                                                   Facebook Likes - Actor 1  \
# Title
# Intolerance: Love's Struggle Throughout the Ages                       436
# Over the Hill to the Poorhouse                                           2
# The Big Parade                                                          81
# Metropolis                                                             136
# Pandora's Box                                                          426
#
#                                                   Facebook Likes - Actor 2  \
# Title
# Intolerance: Love's Struggle Throughout the Ages                        22
# Over the Hill to the Poorhouse                                           2
# The Big Parade                                                          12
# Metropolis                                                              23
# Pandora's Box                                                           20
#
#                                                   Facebook Likes - Actor 3  \
# Title
# Intolerance: Love's Struggle Throughout the Ages                       9.0
# Over the Hill to the Poorhouse                                         0.0
# The Big Parade                                                         6.0
# Metropolis                                                            18.0
# Pandora's Box                                                          3.0
#
#                                                    Facebook Likes - cast Total  \
# Title
# Intolerance: Love's Struggle Throughout the Ages                           481
# Over the Hill to the Poorhouse                                               4
# The Big Parade                                                             108
# Metropolis                                                                 203
# Pandora's Box                                                              455
#
#                                                    Facebook likes - Movie  \
# Title
# Intolerance: Love's Struggle Throughout the Ages                      691
# Over the Hill to the Poorhouse                                          0
# The Big Parade                                                        226
# Metropolis                                                          12000
# Pandora's Box                                                         926
#
#                                                    Facenumber in posters  \
# Title
# Intolerance: Love's Struggle Throughout the Ages                       1
# Over the Hill to the Poorhouse                                         1
# The Big Parade                                                         0
# Metropolis                                                             1
# Pandora's Box                                                          1
#
#                                                    User Votes  \
# Title
# Intolerance: Love's Struggle Throughout the Ages        10718
# Over the Hill to the Poorhouse                              5
# The Big Parade                                           4849
# Metropolis                                             111841
# Pandora's Box                                            7431
#
#                                                    Reviews by Users  \
# Title
# Intolerance: Love's Struggle Throughout the Ages                 88
# Over the Hill to the Poorhouse                                    1
# The Big Parade                                                   45
# Metropolis                                                      413
# Pandora's Box                                                    84
#
#                                                    Reviews by Crtiics  \
# Title
# Intolerance: Love's Struggle Throughout the Ages                 69.0
# Over the Hill to the Poorhouse                                    1.0
# The Big Parade                                                   48.0
# Metropolis                                                      260.0
# Pandora's Box                                                    71.0
#
#                                                    IMDB Score
# Title
# Intolerance: Love's Struggle Throughout the Ages          8.0
# Over the Hill to the Poorhouse                            4.8
# The Big Parade                                            8.3
# Metropolis                                                8.3
# Pandora's Box                                             8.0
#
# [5 rows x 24 columns]

# %% [markdown]
# But it preserves no information about the sheet name. An alternative is to use

# %%
dfs = pd.read_excel('data/movies.xlsx', sheet_name=None)

# %% [markdown]
# To retrieve a dictionary with all the available sheets keyed by name

# %%
len(dfs)
# Out:
# 4

# %%
dfs.keys()
# Out:
# dict_keys(['1900s', '2000s', '2010s', '3000s'])

# %%
movies_1900 = dfs['1900s']

# %%
movies_1900.head()
# Out:
#                                                Title  Year  \
# 0  Intolerance: Love's Struggle Throughout the Ages   1916
# 1                    Over the Hill to the Poorhouse   1920
# 2                                    The Big Parade   1925
# 3                                        Metropolis   1927
# 4                                     Pandora's Box   1929
#
#                 Genres Language  Country Content Rating  Duration  \
# 0    Drama|History|War      NaN      USA      Not Rated       123
# 1          Crime|Drama      NaN      USA            NaN       110
# 2    Drama|Romance|War      NaN      USA      Not Rated       151
# 3         Drama|Sci-Fi   German  Germany      Not Rated       145
# 4  Crime|Drama|Romance   German  Germany      Not Rated       110
#
#    Aspect Ratio     Budget  Gross Earnings  ... Facebook Likes - Actor 1  \
# 0          1.33   385907.0             NaN  ...                      436
# 1          1.33   100000.0       3000000.0  ...                        2
# 2          1.33   245000.0             NaN  ...                       81
# 3          1.33  6000000.0         26435.0  ...                      136
# 4          1.33        NaN          9950.0  ...                      426
#
#   Facebook Likes - Actor 2 Facebook Likes - Actor 3  \
# 0                       22                      9.0
# 1                        2                      0.0
# 2                       12                      6.0
# 3                       23                     18.0
# 4                       20                      3.0
#
#   Facebook Likes - cast Total  Facebook likes - Movie  Facenumber in posters  \
# 0                         481                     691                      1
# 1                           4                       0                      1
# 2                         108                     226                      0
# 3                         203                   12000                      1
# 4                         455                     926                      1
#
#    User Votes  Reviews by Users  Reviews by Crtiics  IMDB Score
# 0       10718                88                69.0         8.0
# 1           5                 1                 1.0         4.8
# 2        4849                45                48.0         8.3
# 3      111841               413               260.0         8.3
# 4        7431                84                71.0         8.0
#
# [5 rows x 25 columns]

# %% [markdown]
# Or to select a specific work sheet directly by name

# %%
movies_2000 = pd.read_excel('data/movies.xlsx', sheet_name='2000s')

# %%
movies_2000.head()
# Out:
#                     Title  Year                   Genres Language Country  \
# 0         102 Dalmatians   2000  Adventure|Comedy|Family  English     USA
# 1                28 Days   2000             Comedy|Drama  English     USA
# 2              3 Strikes   2000                   Comedy  English     USA
# 3               Aberdeen   2000                    Drama  English      UK
# 4  All the Pretty Horses   2000    Drama|Romance|Western  English     USA
#
#   Content Rating  Duration  Aspect Ratio      Budget  Gross Earnings  ...  \
# 0              G     100.0          1.85  85000000.0      66941559.0  ...
# 1          PG-13     103.0          1.37  43000000.0      37035515.0  ...
# 2              R      82.0          1.85   6000000.0       9821335.0  ...
# 3            NaN     106.0          1.85   6500000.0         64148.0  ...
# 4          PG-13     220.0          2.35  57000000.0      15527125.0  ...
#
#   Facebook Likes - Actor 1 Facebook Likes - Actor 2 Facebook Likes - Actor 3  \
# 0                   2000.0                    795.0                    439.0
# 1                  12000.0                  10000.0                    664.0
# 2                    939.0                    706.0                    585.0
# 3                    844.0                      2.0                      0.0
# 4                  13000.0                    861.0                    820.0
#
#   Facebook Likes - cast Total  Facebook likes - Movie  Facenumber in posters  \
# 0                        4182                     372                      1
# 1                       23864                       0                      1
# 2                        3354                     118                      1
# 3                         846                     260                      0
# 4                       15006                     652                      2
#
#    User Votes  Reviews by Users  Reviews by Crtiics  IMDB Score
# 0       26413              77.0                84.0         4.8
# 1       34597             194.0               116.0         6.0
# 2        1415              10.0                22.0         4.0
# 3        2601              35.0                28.0         7.3
# 4       11388             183.0                85.0         5.8
#
# [5 rows x 25 columns]

# %% [markdown]
# If the cells contain formulas, pandas simply returns the current values (the current output of each formula)

# %%
mortgage = pd.read_excel('data/excel-mortgage-calculator.xlsx', skiprows=15)

# %%
mortgage
# Out:
#      Unnamed: 0  PMT NO PAYMENT DATE  BEGINNING BALANCE  SCHEDULED PAYMENT  \
# 0           NaN       1   2020-09-01      200000.000000        1073.643246
# 1           NaN       2   2020-10-01      199659.690087        1073.643246
# 2           NaN       3   2020-11-01      199317.962217        1073.643246
# 3           NaN       4   2020-12-01      198974.810480        1073.643246
# 4           NaN       5   2021-01-01      198630.228944        1073.643246
# ..          ...     ...          ...                ...                ...
# 355         NaN     356   2050-04-01           0.000000        1073.643246
# 356         NaN     357   2050-05-01           0.000000        1073.643246
# 357         NaN     358   2050-06-01           0.000000        1073.643246
# 358         NaN     359   2050-07-01           0.000000        1073.643246
# 359         NaN     360   2050-08-01           0.000000        1073.643246
#
#      EXTRA PAYMENT  TOTAL PAYMENT   PRINCIPAL    INTEREST  ENDING BALANCE  \
# 0              100    1173.643246  340.309913  833.333333   199659.690087
# 1              100    1173.643246  341.727871  831.915375   199317.962217
# 2              100    1173.643246  343.151737  830.491509   198974.810480
# 3              100    1173.643246  344.581536  829.061710   198630.228944
# 4              100    1173.643246  346.017292  827.625954   198284.211652
# ..             ...            ...         ...         ...             ...
# 355              0       0.000000    0.000000    0.000000        0.000000
# 356              0       0.000000    0.000000    0.000000        0.000000
# 357              0       0.000000    0.000000    0.000000        0.000000
# 358              0       0.000000    0.000000    0.000000        0.000000
# 359              0       0.000000    0.000000    0.000000        0.000000
#
#      CUMULATIVE INTEREST
# 0             833.333333
# 1            1665.248709
# 2            2495.740218
# 3            3324.801928
# 4            4152.427882
# ..                   ...
# 355        149442.538588
# 356        149442.538588
# 357        149442.538588
# 358        149442.538588
# 359        149442.538588
#
# [360 rows x 11 columns]

# %% [markdown]
# Wherever possible, dypes are chosen according to the excel format specified

# %%
mortgage.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 360 entries, 0 to 359
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           0 non-null      float64
#  1   PMT NO               360 non-null    int64
#  2   PAYMENT DATE         360 non-null    datetime64[ns]
#  3   BEGINNING BALANCE    360 non-null    float64
#  4   SCHEDULED PAYMENT    360 non-null    float64
#  5   EXTRA PAYMENT        360 non-null    int64
#  6   TOTAL PAYMENT        360 non-null    float64
#  7   PRINCIPAL            360 non-null    float64
#  8   INTEREST             360 non-null    float64
#  9   ENDING BALANCE       360 non-null    float64
#  10  CUMULATIVE INTEREST  360 non-null    float64
# dtypes: datetime64[ns](1), float64(8), int64(2)
# memory usage: 31.1 KB

# %% [markdown]
# ### ExcelFile

# %%
book = pd.ExcelFile('data/movies.xlsx')

# %% [markdown]
# We can easily get a list of all worksheets

# %%
book.sheet_names
# Out:
# ['1900s', '2000s', '2010s', '3000s']

# %% [markdown]
# We can easily parse a specific sheet and convert it to a DataFrame

# %%
df3 = book.parse('2000s')

# %%
df3.head()
# Out:
#                     Title  Year                   Genres Language Country  \
# 0         102 Dalmatians   2000  Adventure|Comedy|Family  English     USA
# 1                28 Days   2000             Comedy|Drama  English     USA
# 2              3 Strikes   2000                   Comedy  English     USA
# 3               Aberdeen   2000                    Drama  English      UK
# 4  All the Pretty Horses   2000    Drama|Romance|Western  English     USA
#
#   Content Rating  Duration  Aspect Ratio      Budget  Gross Earnings  ...  \
# 0              G     100.0          1.85  85000000.0      66941559.0  ...
# 1          PG-13     103.0          1.37  43000000.0      37035515.0  ...
# 2              R      82.0          1.85   6000000.0       9821335.0  ...
# 3            NaN     106.0          1.85   6500000.0         64148.0  ...
# 4          PG-13     220.0          2.35  57000000.0      15527125.0  ...
#
#   Facebook Likes - Actor 1 Facebook Likes - Actor 2 Facebook Likes - Actor 3  \
# 0                   2000.0                    795.0                    439.0
# 1                  12000.0                  10000.0                    664.0
# 2                    939.0                    706.0                    585.0
# 3                    844.0                      2.0                      0.0
# 4                  13000.0                    861.0                    820.0
#
#   Facebook Likes - cast Total  Facebook likes - Movie  Facenumber in posters  \
# 0                        4182                     372                      1
# 1                       23864                       0                      1
# 2                        3354                     118                      1
# 3                         846                     260                      0
# 4                       15006                     652                      2
#
#    User Votes  Reviews by Users  Reviews by Crtiics  IMDB Score
# 0       26413              77.0                84.0         4.8
# 1       34597             194.0               116.0         6.0
# 2        1415              10.0                22.0         4.0
# 3        2601              35.0                28.0         7.3
# 4       11388             183.0                85.0         5.8
#
# [5 rows x 25 columns]

# %% [markdown]
# __parse__ supports most of the parameters available for read_excel

# %%
df4 = book.parse('2000s', index_col=0, usecols=['Title', 'Year', 'Director', 'Budget'])

# %%
df4.head()
# Out:
#                         Year      Budget            Director
# Title
# 102 Dalmatians          2000  85000000.0          Kevin Lima
# 28 Days                 2000  43000000.0        Betty Thomas
# 3 Strikes               2000   6000000.0             DJ Pooh
# Aberdeen                2000   6500000.0  Hans Petter Moland
# All the Pretty Horses   2000  57000000.0  Billy Bob Thornton

# %% [markdown]
# ### Web pages

# %% [markdown]
# We're going to use the Wikipedia page with the current numbers of cases for CoVID-19

# %%
url = 'https://en.wikipedia.org/wiki/COVID-19_pandemic_by_country_and_territory'

# %% [markdown]
# All we have to do is to provide the url

# %%
dfs = pd.read_html(url)

# %% [markdown]
# Which retrieves all the tables in the page, in the order they appear

# %%
len(dfs)
# Out:
# 32

# %% [markdown]
# So the first one is the infobox on the top right hand corner

# %%
dfs[0]
# Out:
#                                     COVID-19 pandemic  \
# 0   Confirmed cases per 100,000 population as of 2...
# 1                                             Disease
# 2                                        Virus strain
# 3                                              Source
# 4                                            Location
# 5                                      First outbreak
# 6                                          Index case
# 7                                                Date
# 8                                     Confirmed cases
# 9                                        Active cases
# 10                                          Recovered
# 11                                             Deaths
# 12                                        Territories
#
#                                   COVID-19 pandemic.1
# 0   Confirmed cases per 100,000 population as of 2...
# 1                 Coronavirus disease 2019 (COVID-19)
# 2   Severe acute respiratory syndromecoronavirus 2...
# 3         Probably bats, possibly via pangolins[1][2]
# 4                                           Worldwide
# 5                                   Mainland China[3]
# 6   Wuhan, Hubei, China30°37′11″N 114°15′28″E﻿ / ﻿...
# 7     1 December 2019[3]–present(9 months and 2 days)
# 8                                       26,062,946[4]
# 9                                        7,882,999[4]
# 10                                      17,316,206[4]
# 11                                         863,741[4]
# 12                                             188[4]

# %% [markdown]
# And the second one is the number of cases and deaths per country

# %%
dfs[1]
# Out:
#                                            Location[a]  \
#                                     Unnamed: 0_level_1
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 225                                                NaN
# 226                                                NaN
# 227                                                NaN
# 228  As of 3 September 2020 (UTC) · History of case...
# 229  Notes ^ Location: Countries, territories, and ...
#
#                                                         \
#                                               World[e]
# 0                                     United States[f]
# 1                                            Brazil[g]
# 2                                                India
# 3                                            Russia[h]
# 4                                                 Peru
# ..                                                 ...
# 225                                           Anguilla
# 226                                     Sint Eustatius
# 227                                       Tanzania[bd]
# 228  As of 3 September 2020 (UTC) · History of case...
# 229  Notes ^ Location: Countries, territories, and ...
#
#                                               Cases[b]  \
#                                             26,062,946
# 0                                              6206224
# 1                                              4001422
# 2                                              3853406
# 3                                              1009995
# 4                                               663437
# ..                                                 ...
# 225                                                  3
# 226                                                  2
# 227                                            No data
# 228  As of 3 September 2020 (UTC) · History of case...
# 229  Notes ^ Location: Countries, territories, and ...
#
#                                              Deaths[c]  \
#                                                863,741
# 0                                               188590
# 1                                               123899
# 2                                                67376
# 3                                                17528
# 4                                                29259
# ..                                                 ...
# 225                                                  0
# 226                                                  0
# 227                                            No data
# 228  As of 3 September 2020 (UTC) · History of case...
# 229  Notes ^ Location: Countries, territories, and ...
#
#                                              Recov.[d]  \
#                                             17,316,206
# 0                                              3280930
# 1                                              3210405
# 2                                              2970492
# 3                                               826935
# 4                                               480177
# ..                                                 ...
# 225                                                  3
# 226                                                  2
# 227                                            No data
# 228  As of 3 September 2020 (UTC) · History of case...
# 229  Notes ^ Location: Countries, territories, and ...
#
#                                                   Ref.
#                                                    [4]
# 0                                                 [13]
# 1                                             [16][17]
# 2                                                 [18]
# 3                                                 [19]
# 4                                             [20][21]
# ..                                                 ...
# 225                                              [317]
# 226                                              [318]
# 227                                         [320][321]
# 228  As of 3 September 2020 (UTC) · History of case...
# 229  Notes ^ Location: Countries, territories, and ...
#
# [230 rows x 6 columns]

# %% [markdown]
# Due to the formatting of the table, pandas interpreted the first two rows to be the headers. We can fix this by explicitly telling it to just use the first row for the column headers

# %%
dfs = pd.read_html(url, header=0)

# %%
dfs[1]
# Out:
#                                            Location[a]  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 226                                                NaN
# 227                                                NaN
# 228                                                NaN
# 229  As of 3 September 2020 (UTC) · History of case...
# 230  Notes ^ Location: Countries, territories, and ...
#
#                                          Location[a].1  \
# 0                                             World[e]
# 1                                     United States[f]
# 2                                            Brazil[g]
# 3                                                India
# 4                                            Russia[h]
# ..                                                 ...
# 226                                           Anguilla
# 227                                     Sint Eustatius
# 228                                       Tanzania[bd]
# 229  As of 3 September 2020 (UTC) · History of case...
# 230  Notes ^ Location: Countries, territories, and ...
#
#                                               Cases[b]  \
# 0                                             26062946
# 1                                              6206224
# 2                                              4001422
# 3                                              3853406
# 4                                              1009995
# ..                                                 ...
# 226                                                  3
# 227                                                  2
# 228                                            No data
# 229  As of 3 September 2020 (UTC) · History of case...
# 230  Notes ^ Location: Countries, territories, and ...
#
#                                              Deaths[c]  \
# 0                                               863741
# 1                                               188590
# 2                                               123899
# 3                                                67376
# 4                                                17528
# ..                                                 ...
# 226                                                  0
# 227                                                  0
# 228                                            No data
# 229  As of 3 September 2020 (UTC) · History of case...
# 230  Notes ^ Location: Countries, territories, and ...
#
#                                              Recov.[d]  \
# 0                                             17316206
# 1                                              3280930
# 2                                              3210405
# 3                                              2970492
# 4                                               826935
# ..                                                 ...
# 226                                                  3
# 227                                                  2
# 228                                            No data
# 229  As of 3 September 2020 (UTC) · History of case...
# 230  Notes ^ Location: Countries, territories, and ...
#
#                                                   Ref.
# 0                                                  [4]
# 1                                                 [13]
# 2                                             [16][17]
# 3                                                 [18]
# 4                                                 [19]
# ..                                                 ...
# 226                                              [317]
# 227                                              [318]
# 228                                         [320][321]
# 229  As of 3 September 2020 (UTC) · History of case...
# 230  Notes ^ Location: Countries, territories, and ...
#
# [231 rows x 6 columns]

# %% [markdown]
# ## Subsetting

# %% [markdown]
# The top/bottom N number of values are easy to access

# %%
movies.head(10)
# Out:
#                                                    Year  \
# Title
# Intolerance: Love's Struggle Throughout the Ages   1916
# Over the Hill to the Poorhouse                     1920
# The Big Parade                                     1925
# Metropolis                                         1927
# Pandora's Box                                      1929
# The Broadway Melody                                1929
# Hell's Angels                                      1930
# A Farewell to Arms                                 1932
# 42nd Street                                        1933
# She Done Him Wrong                                 1933
#
#                                                                                  Genres  \
# Title
# Intolerance: Love's Struggle Throughout the Ages                      Drama|History|War
# Over the Hill to the Poorhouse                                              Crime|Drama
# The Big Parade                                                        Drama|Romance|War
# Metropolis                                                                 Drama|Sci-Fi
# Pandora's Box                                                       Crime|Drama|Romance
# The Broadway Melody                                                     Musical|Romance
# Hell's Angels                                                                 Drama|War
# A Farewell to Arms                                                    Drama|Romance|War
# 42nd Street                                                      Comedy|Musical|Romance
# She Done Him Wrong                                 Comedy|Drama|History|Musical|Romance
#
#                                                   Language  Country  \
# Title
# Intolerance: Love's Struggle Throughout the Ages       NaN      USA
# Over the Hill to the Poorhouse                         NaN      USA
# The Big Parade                                         NaN      USA
# Metropolis                                          German  Germany
# Pandora's Box                                       German  Germany
# The Broadway Melody                                English      USA
# Hell's Angels                                      English      USA
# A Farewell to Arms                                 English      USA
# 42nd Street                                        English      USA
# She Done Him Wrong                                 English      USA
#
#                                                   Content Rating  Duration  \
# Title
# Intolerance: Love's Struggle Throughout the Ages       Not Rated       123
# Over the Hill to the Poorhouse                               NaN       110
# The Big Parade                                         Not Rated       151
# Metropolis                                             Not Rated       145
# Pandora's Box                                          Not Rated       110
# The Broadway Melody                                       Passed       100
# Hell's Angels                                             Passed        96
# A Farewell to Arms                                       Unrated        79
# 42nd Street                                              Unrated        89
# She Done Him Wrong                                      Approved        66
#
#                                                    Aspect Ratio     Budget  \
# Title
# Intolerance: Love's Struggle Throughout the Ages           1.33   385907.0
# Over the Hill to the Poorhouse                             1.33   100000.0
# The Big Parade                                             1.33   245000.0
# Metropolis                                                 1.33  6000000.0
# Pandora's Box                                              1.33        NaN
# The Broadway Melody                                        1.37   379000.0
# Hell's Angels                                              1.20  3950000.0
# A Farewell to Arms                                         1.37   800000.0
# 42nd Street                                                1.37   439000.0
# She Done Him Wrong                                         1.37   200000.0
#
#                                                    Gross Earnings  \
# Title
# Intolerance: Love's Struggle Throughout the Ages              NaN
# Over the Hill to the Poorhouse                          3000000.0
# The Big Parade                                                NaN
# Metropolis                                                26435.0
# Pandora's Box                                              9950.0
# The Broadway Melody                                     2808000.0
# Hell's Angels                                                 NaN
# A Farewell to Arms                                            NaN
# 42nd Street                                             2300000.0
# She Done Him Wrong                                            NaN
#
#                                                               Director  ...  \
# Title                                                                   ...
# Intolerance: Love's Struggle Throughout the Ages         D.W. Griffith  ...
# Over the Hill to the Poorhouse                       Harry F. Millarde  ...
# The Big Parade                                              King Vidor  ...
# Metropolis                                                  Fritz Lang  ...
# Pandora's Box                                      Georg Wilhelm Pabst  ...
# The Broadway Melody                                     Harry Beaumont  ...
# Hell's Angels                                            Howard Hughes  ...
# A Farewell to Arms                                       Frank Borzage  ...
# 42nd Street                                                Lloyd Bacon  ...
# She Done Him Wrong                                      Lowell Sherman  ...
#
#                                                   Facebook Likes - Actor 1  \
# Title
# Intolerance: Love's Struggle Throughout the Ages                       436
# Over the Hill to the Poorhouse                                           2
# The Big Parade                                                          81
# Metropolis                                                             136
# Pandora's Box                                                          426
# The Broadway Melody                                                     77
# Hell's Angels                                                          431
# A Farewell to Arms                                                     998
# 42nd Street                                                            610
# She Done Him Wrong                                                     418
#
#                                                   Facebook Likes - Actor 2  \
# Title
# Intolerance: Love's Struggle Throughout the Ages                        22
# Over the Hill to the Poorhouse                                           2
# The Big Parade                                                          12
# Metropolis                                                              23
# Pandora's Box                                                           20
# The Broadway Melody                                                     28
# Hell's Angels                                                           12
# A Farewell to Arms                                                     164
# 42nd Street                                                            105
# She Done Him Wrong                                                      85
#
#                                                   Facebook Likes - Actor 3  \
# Title
# Intolerance: Love's Struggle Throughout the Ages                       9.0
# Over the Hill to the Poorhouse                                         0.0
# The Big Parade                                                         6.0
# Metropolis                                                            18.0
# Pandora's Box                                                          3.0
# The Broadway Melody                                                    4.0
# Hell's Angels                                                          4.0
# A Farewell to Arms                                                    99.0
# 42nd Street                                                           45.0
# She Done Him Wrong                                                    28.0
#
#                                                    Facebook Likes - cast Total  \
# Title
# Intolerance: Love's Struggle Throughout the Ages                           481
# Over the Hill to the Poorhouse                                               4
# The Big Parade                                                             108
# Metropolis                                                                 203
# Pandora's Box                                                              455
# The Broadway Melody                                                        109
# Hell's Angels                                                              457
# A Farewell to Arms                                                        1284
# 42nd Street                                                                995
# She Done Him Wrong                                                         583
#
#                                                    Facebook likes - Movie  \
# Title
# Intolerance: Love's Struggle Throughout the Ages                      691
# Over the Hill to the Poorhouse                                          0
# The Big Parade                                                        226
# Metropolis                                                          12000
# Pandora's Box                                                         926
# The Broadway Melody                                                   167
# Hell's Angels                                                         279
# A Farewell to Arms                                                    213
# 42nd Street                                                           439
# She Done Him Wrong                                                    328
#
#                                                    Facenumber in posters  \
# Title
# Intolerance: Love's Struggle Throughout the Ages                       1
# Over the Hill to the Poorhouse                                         1
# The Big Parade                                                         0
# Metropolis                                                             1
# Pandora's Box                                                          1
# The Broadway Melody                                                    8
# Hell's Angels                                                          1
# A Farewell to Arms                                                     1
# 42nd Street                                                            2
# She Done Him Wrong                                                     1
#
#                                                    User Votes  \
# Title
# Intolerance: Love's Struggle Throughout the Ages        10718
# Over the Hill to the Poorhouse                              5
# The Big Parade                                           4849
# Metropolis                                             111841
# Pandora's Box                                            7431
# The Broadway Melody                                      4546
# Hell's Angels                                            3753
# A Farewell to Arms                                       3519
# 42nd Street                                              7921
# She Done Him Wrong                                       4152
#
#                                                    Reviews by Users  \
# Title
# Intolerance: Love's Struggle Throughout the Ages                 88
# Over the Hill to the Poorhouse                                    1
# The Big Parade                                                   45
# Metropolis                                                      413
# Pandora's Box                                                    84
# The Broadway Melody                                              71
# Hell's Angels                                                    53
# A Farewell to Arms                                               46
# 42nd Street                                                      97
# She Done Him Wrong                                               59
#
#                                                    Reviews by Crtiics  \
# Title
# Intolerance: Love's Struggle Throughout the Ages                 69.0
# Over the Hill to the Poorhouse                                    1.0
# The Big Parade                                                   48.0
# Metropolis                                                      260.0
# Pandora's Box                                                    71.0
# The Broadway Melody                                              36.0
# Hell's Angels                                                    35.0
# A Farewell to Arms                                               42.0
# 42nd Street                                                      65.0
# She Done Him Wrong                                               35.0
#
#                                                    IMDB Score
# Title
# Intolerance: Love's Struggle Throughout the Ages          8.0
# Over the Hill to the Poorhouse                            4.8
# The Big Parade                                            8.3
# Metropolis                                                8.3
# Pandora's Box                                             8.0
# The Broadway Melody                                       6.3
# Hell's Angels                                             7.8
# A Farewell to Arms                                        6.6
# 42nd Street                                               7.7
# She Done Him Wrong                                        6.5
#
# [10 rows x 24 columns]

# %%
movies.tail(2)
# Out:
#                  Year                        Genres Language Country  \
# Title
# Wild Wild West   1999  Action|Comedy|Sci-Fi|Western  English     USA
# Wing Commander   1999       Action|Adventure|Sci-Fi  English     USA
#
#                 Content Rating  Duration  Aspect Ratio       Budget  \
# Title
# Wild Wild West           PG-13       106          1.85  170000000.0
# Wing Commander           PG-13       100          2.35   30000000.0
#
#                  Gross Earnings          Director  ...  \
# Title                                              ...
# Wild Wild West      113745408.0  Barry Sonnenfeld  ...
# Wing Commander       11576087.0     Chris Roberts  ...
#
#                 Facebook Likes - Actor 1 Facebook Likes - Actor 2  \
# Title
# Wild Wild West                     10000                     4000
# Wing Commander                       811                      586
#
#                 Facebook Likes - Actor 3  Facebook Likes - cast Total  \
# Title
# Wild Wild West                     582.0                        15870
# Wing Commander                     362.0                         2497
#
#                  Facebook likes - Movie  Facenumber in posters  User Votes  \
# Title
# Wild Wild West                        0                      2      129601
# Wing Commander                      858                      3       14747
#
#                  Reviews by Users  Reviews by Crtiics  IMDB Score
# Title
# Wild Wild West                648                85.0         4.8
# Wing Commander                338                85.0         4.1
#
# [2 rows x 24 columns]

# %% [markdown]
# And individual rows, which can be indexed by Name

# %%
movies.loc["Wild Wild West\xa0"]
# Out:
# Year                                                   1999
# Genres                         Action|Comedy|Sci-Fi|Western
# Language                                            English
# Country                                                 USA
# Content Rating                                        PG-13
# Duration                                                106
# Aspect Ratio                                           1.85
# Budget                                              1.7e+08
# Gross Earnings                                  1.13745e+08
# Director                                   Barry Sonnenfeld
# Actor 1                                          Will Smith
# Actor 2                                         Salma Hayek
# Actor 3                                            Bai Ling
# Facebook Likes - Director                               188
# Facebook Likes - Actor 1                              10000
# Facebook Likes - Actor 2                               4000
# Facebook Likes - Actor 3                                582
# Facebook Likes - cast Total                           15870
# Facebook likes - Movie                                    0
# Facenumber in posters                                     2
# User Votes                                           129601
# Reviews by Users                                        648
# Reviews by Crtiics                                       85
# IMDB Score                                              4.8
# Name: Wild Wild West , dtype: object

# %% [markdown]
# Or by position

# %%
movies.iloc[1336]
# Out:
# Year                                                   1999
# Genres                         Action|Comedy|Sci-Fi|Western
# Language                                            English
# Country                                                 USA
# Content Rating                                        PG-13
# Duration                                                106
# Aspect Ratio                                           1.85
# Budget                                              1.7e+08
# Gross Earnings                                  1.13745e+08
# Director                                   Barry Sonnenfeld
# Actor 1                                          Will Smith
# Actor 2                                         Salma Hayek
# Actor 3                                            Bai Ling
# Facebook Likes - Director                               188
# Facebook Likes - Actor 1                              10000
# Facebook Likes - Actor 2                               4000
# Facebook Likes - Actor 3                                582
# Facebook Likes - cast Total                           15870
# Facebook likes - Movie                                    0
# Facenumber in posters                                     2
# User Votes                                           129601
# Reviews by Users                                        648
# Reviews by Crtiics                                       85
# IMDB Score                                              4.8
# Name: Wild Wild West , dtype: object

# %% [markdown]
# Rows behave a named tuples, so you can access individual elements by position:

# %%
movies.iloc[1336, 10]
# Out:
# 'Will Smith'

# %% [markdown]
# Or by name

# %%
movies.iloc[1336].Budget
# Out:
# 170000000.0

# %%
movies.loc['Wild Wild West\xa0', 'Director']
# Out:
# 'Barry Sonnenfeld'

# %% [markdown]
# Ranges can also be used with iloc

# %%
movies.iloc[1:4]
# Out:
#                                  Year             Genres Language  Country  \
# Title
# Over the Hill to the Poorhouse   1920        Crime|Drama      NaN      USA
# The Big Parade                   1925  Drama|Romance|War      NaN      USA
# Metropolis                       1927       Drama|Sci-Fi   German  Germany
#
#                                 Content Rating  Duration  Aspect Ratio  \
# Title
# Over the Hill to the Poorhouse             NaN       110          1.33
# The Big Parade                       Not Rated       151          1.33
# Metropolis                           Not Rated       145          1.33
#
#                                     Budget  Gross Earnings           Director  \
# Title
# Over the Hill to the Poorhouse    100000.0       3000000.0  Harry F. Millarde
# The Big Parade                    245000.0             NaN         King Vidor
# Metropolis                       6000000.0         26435.0         Fritz Lang
#
#                                  ... Facebook Likes - Actor 1  \
# Title                            ...
# Over the Hill to the Poorhouse   ...                        2
# The Big Parade                   ...                       81
# Metropolis                       ...                      136
#
#                                 Facebook Likes - Actor 2  \
# Title
# Over the Hill to the Poorhouse                         2
# The Big Parade                                        12
# Metropolis                                            23
#
#                                 Facebook Likes - Actor 3  \
# Title
# Over the Hill to the Poorhouse                       0.0
# The Big Parade                                       6.0
# Metropolis                                          18.0
#
#                                  Facebook Likes - cast Total  \
# Title
# Over the Hill to the Poorhouse                             4
# The Big Parade                                           108
# Metropolis                                               203
#
#                                  Facebook likes - Movie  \
# Title
# Over the Hill to the Poorhouse                        0
# The Big Parade                                      226
# Metropolis                                        12000
#
#                                  Facenumber in posters  User Votes  \
# Title
# Over the Hill to the Poorhouse                       1           5
# The Big Parade                                       0        4849
# Metropolis                                           1      111841
#
#                                  Reviews by Users  Reviews by Crtiics  \
# Title
# Over the Hill to the Poorhouse                  1                 1.0
# The Big Parade                                 45                48.0
# Metropolis                                    413               260.0
#
#                                  IMDB Score
# Title
# Over the Hill to the Poorhouse          4.8
# The Big Parade                          8.3
# Metropolis                              8.3
#
# [3 rows x 24 columns]

# %% [markdown]
# And __loc__ with the important difference that loc automatically __includes__ the last value of the range, while iloc does not

# %%
movies.loc["Over the Hill to the Poorhouse\xa0":"Metropolis\xa0"]
# Out:
#                                  Year             Genres Language  Country  \
# Title
# Over the Hill to the Poorhouse   1920        Crime|Drama      NaN      USA
# The Big Parade                   1925  Drama|Romance|War      NaN      USA
# Metropolis                       1927       Drama|Sci-Fi   German  Germany
#
#                                 Content Rating  Duration  Aspect Ratio  \
# Title
# Over the Hill to the Poorhouse             NaN       110          1.33
# The Big Parade                       Not Rated       151          1.33
# Metropolis                           Not Rated       145          1.33
#
#                                     Budget  Gross Earnings           Director  \
# Title
# Over the Hill to the Poorhouse    100000.0       3000000.0  Harry F. Millarde
# The Big Parade                    245000.0             NaN         King Vidor
# Metropolis                       6000000.0         26435.0         Fritz Lang
#
#                                  ... Facebook Likes - Actor 1  \
# Title                            ...
# Over the Hill to the Poorhouse   ...                        2
# The Big Parade                   ...                       81
# Metropolis                       ...                      136
#
#                                 Facebook Likes - Actor 2  \
# Title
# Over the Hill to the Poorhouse                         2
# The Big Parade                                        12
# Metropolis                                            23
#
#                                 Facebook Likes - Actor 3  \
# Title
# Over the Hill to the Poorhouse                       0.0
# The Big Parade                                       6.0
# Metropolis                                          18.0
#
#                                  Facebook Likes - cast Total  \
# Title
# Over the Hill to the Poorhouse                             4
# The Big Parade                                           108
# Metropolis                                               203
#
#                                  Facebook likes - Movie  \
# Title
# Over the Hill to the Poorhouse                        0
# The Big Parade                                      226
# Metropolis                                        12000
#
#                                  Facenumber in posters  User Votes  \
# Title
# Over the Hill to the Poorhouse                       1           5
# The Big Parade                                       0        4849
# Metropolis                                           1      111841
#
#                                  Reviews by Users  Reviews by Crtiics  \
# Title
# Over the Hill to the Poorhouse                  1                 1.0
# The Big Parade                                 45                48.0
# Metropolis                                    413               260.0
#
#                                  IMDB Score
# Title
# Over the Hill to the Poorhouse          4.8
# The Big Parade                          8.3
# Metropolis                              8.3
#
# [3 rows x 24 columns]

# %% [markdown]
# Since each column is just a numpy array, we can easily manipulate the values and create new columns

# %%
movies['Budget2'] = movies.Budget+45

# %%
movies[['Budget', 'Budget2']]
# Out:
#                                                         Budget      Budget2
# Title
# Intolerance: Love's Struggle Throughout the Ages      385907.0     385952.0
# Over the Hill to the Poorhouse                        100000.0     100045.0
# The Big Parade                                        245000.0     245045.0
# Metropolis                                           6000000.0    6000045.0
# Pandora's Box                                              NaN          NaN
# ...                                                        ...          ...
# Twin Falls Idaho                                      500000.0     500045.0
# Universal Soldier: The Return                       24000000.0   24000045.0
# Varsity Blues                                       16000000.0   16000045.0
# Wild Wild West                                     170000000.0  170000045.0
# Wing Commander                                      30000000.0   30000045.0
#
# [1338 rows x 2 columns]

# %% [markdown]
# We can also append new rows to the dataframe. Since we have 3 sheets that all follow the same format, we can just stack them together using __concat__:

# %%
df2 = pd.concat([movies, movies_2000])

# %%
df2
# Out:
#                                                    Year  \
# Intolerance: Love's Struggle Throughout the Ages   1916
# Over the Hill to the Poorhouse                     1920
# The Big Parade                                     1925
# Metropolis                                         1927
# Pandora's Box                                      1929
# ...                                                 ...
# 2095                                               2009
# 2096                                               2009
# 2097                                               2009
# 2098                                               2009
# 2099                                               2009
#
#                                                                                      Genres  \
# Intolerance: Love's Struggle Throughout the Ages                          Drama|History|War
# Over the Hill to the Poorhouse                                                  Crime|Drama
# The Big Parade                                                            Drama|Romance|War
# Metropolis                                                                     Drama|Sci-Fi
# Pandora's Box                                                           Crime|Drama|Romance
# ...                                                                                     ...
# 2095                                               Action|Adventure|Fantasy|Sci-Fi|Thriller
# 2096                                                                       Adventure|Comedy
# 2097                                                                   Comedy|Drama|Romance
# 2098                                                                   Comedy|Horror|Sci-Fi
# 2099                                                         Adventure|Comedy|Horror|Sci-Fi
#
#                                                   Language  Country  \
# Intolerance: Love's Struggle Throughout the Ages       NaN      USA
# Over the Hill to the Poorhouse                         NaN      USA
# The Big Parade                                         NaN      USA
# Metropolis                                          German  Germany
# Pandora's Box                                       German  Germany
# ...                                                    ...      ...
# 2095                                               English      USA
# 2096                                               English      USA
# 2097                                               English      USA
# 2098                                               English      USA
# 2099                                               English      USA
#
#                                                   Content Rating  Duration  \
# Intolerance: Love's Struggle Throughout the Ages       Not Rated     123.0
# Over the Hill to the Poorhouse                               NaN     110.0
# The Big Parade                                         Not Rated     151.0
# Metropolis                                             Not Rated     145.0
# Pandora's Box                                          Not Rated     110.0
# ...                                                          ...       ...
# 2095                                                       PG-13     119.0
# 2096                                                       PG-13     100.0
# 2097                                                           R      90.0
# 2098                                                           R      89.0
# 2099                                                           R      88.0
#
#                                                    Aspect Ratio       Budget  \
# Intolerance: Love's Struggle Throughout the Ages           1.33     385907.0
# Over the Hill to the Poorhouse                             1.33     100000.0
# The Big Parade                                             1.33     245000.0
# Metropolis                                                 1.33    6000000.0
# Pandora's Box                                              1.33          NaN
# ...                                                         ...          ...
# 2095                                                       2.35  150000000.0
# 2096                                                       1.85   60000000.0
# 2097                                                       1.85   18000000.0
# 2098                                                       1.85     500000.0
# 2099                                                       2.35   23600000.0
#
#                                                    Gross Earnings  \
# Intolerance: Love's Struggle Throughout the Ages              NaN
# Over the Hill to the Poorhouse                          3000000.0
# The Big Parade                                                NaN
# Metropolis                                                26435.0
# Pandora's Box                                              9950.0
# ...                                                           ...
# 2095                                                  179883016.0
# 2096                                                   43337279.0
# 2097                                                   15281286.0
# 2098                                                          NaN
# 2099                                                   75590286.0
#
#                                                               Director  ...  \
# Intolerance: Love's Struggle Throughout the Ages         D.W. Griffith  ...
# Over the Hill to the Poorhouse                       Harry F. Millarde  ...
# The Big Parade                                              King Vidor  ...
# Metropolis                                                  Fritz Lang  ...
# Pandora's Box                                      Georg Wilhelm Pabst  ...
# ...                                                                ...  ...
# 2095                                                        Gavin Hood  ...
# 2096                                                      Harold Ramis  ...
# 2097                                                     Miguel Arteta  ...
# 2098                                                    Kevin Hamedani  ...
# 2099                                                   Ruben Fleischer  ...
#
#                                                   Facebook Likes - Actor 3  \
# Intolerance: Love's Struggle Throughout the Ages                       9.0
# Over the Hill to the Poorhouse                                         0.0
# The Big Parade                                                         6.0
# Metropolis                                                            18.0
# Pandora's Box                                                          3.0
# ...                                                                    ...
# 2095                                                                2000.0
# 2096                                                                 485.0
# 2097                                                                 729.0
# 2098                                                                  23.0
# 2099                                                                  11.0
#
#                                                   Facebook Likes - cast Total  \
# Intolerance: Love's Struggle Throughout the Ages                          481
# Over the Hill to the Poorhouse                                              4
# The Big Parade                                                            108
# Metropolis                                                                203
# Pandora's Box                                                             455
# ...                                                                       ...
# 2095                                                                    40054
# 2096                                                                    12258
# 2097                                                                    16004
# 2098                                                                      292
# 2099                                                                    28011
#
#                                                   Facebook likes - Movie  \
# Intolerance: Love's Struggle Throughout the Ages                     691
# Over the Hill to the Poorhouse                                         0
# The Big Parade                                                       226
# Metropolis                                                         12000
# Pandora's Box                                                        926
# ...                                                                  ...
# 2095                                                                   0
# 2096                                                                   0
# 2097                                                                   0
# 2098                                                                   0
# 2099                                                               26000
#
#                                                    Facenumber in posters  \
# Intolerance: Love's Struggle Throughout the Ages                       1
# Over the Hill to the Poorhouse                                         1
# The Big Parade                                                         0
# Metropolis                                                             1
# Pandora's Box                                                          1
# ...                                                                  ...
# 2095                                                                   0
# 2096                                                                   2
# 2097                                                                   2
# 2098                                                                   0
# 2099                                                                   4
#
#                                                    User Votes  \
# Intolerance: Love's Struggle Throughout the Ages        10718
# Over the Hill to the Poorhouse                              5
# The Big Parade                                           4849
# Metropolis                                             111841
# Pandora's Box                                            7431
# ...                                                       ...
# 2095                                                   361924
# 2096                                                    76770
# 2097                                                    64646
# 2098                                                     3650
# 2099                                                   386217
#
#                                                    Reviews by Users  \
# Intolerance: Love's Struggle Throughout the Ages               88.0
# Over the Hill to the Poorhouse                                  1.0
# The Big Parade                                                 45.0
# Metropolis                                                    413.0
# Pandora's Box                                                  84.0
# ...                                                             ...
# 2095                                                          641.0
# 2096                                                          203.0
# 2097                                                          105.0
# 2098                                                           39.0
# 2099                                                          553.0
#
#                                                    Reviews by Crtiics  \
# Intolerance: Love's Struggle Throughout the Ages                 69.0
# Over the Hill to the Poorhouse                                    1.0
# The Big Parade                                                   48.0
# Metropolis                                                      260.0
# Pandora's Box                                                    71.0
# ...                                                               ...
# 2095                                                            350.0
# 2096                                                            170.0
# 2097                                                            192.0
# 2098                                                             64.0
# 2099                                                            445.0
#
#                                                    IMDB Score    Budget2  \
# Intolerance: Love's Struggle Throughout the Ages          8.0   385952.0
# Over the Hill to the Poorhouse                            4.8   100045.0
# The Big Parade                                            8.3   245045.0
# Metropolis                                                8.3  6000045.0
# Pandora's Box                                             8.0        NaN
# ...                                                       ...        ...
# 2095                                                      6.7        NaN
# 2096                                                      4.9        NaN
# 2097                                                      6.5        NaN
# 2098                                                      5.1        NaN
# 2099                                                      7.7        NaN
#
#                                                                                Title
# Intolerance: Love's Struggle Throughout the Ages                                 NaN
# Over the Hill to the Poorhouse                                                   NaN
# The Big Parade                                                                   NaN
# Metropolis                                                                       NaN
# Pandora's Box                                                                    NaN
# ...                                                                              ...
# 2095                                                       X-Men Origins: Wolverine
# 2096                                                                       Year One
# 2097                                                                Youth in Revolt
# 2098                                               ZMD: Zombies of Mass Destruction
# 2099                                                                     Zombieland
#
# [3438 rows x 26 columns]

# %% [markdown]
# __concat__ can also be used to place two DataFrames side by side

# %%
pd.concat([movies, movies], axis=1).shape
# Out:
# (1338, 50)

# %% [markdown]
# ## Time Series

# %% [markdown]
# Apple stock information from https://finance.yahoo.com/quote/AAPL/history

# %% [markdown]
# We can automatically convert the Date column using __pd.read_csv__:

# %%
data = pd.read_csv('data/AAPL.csv', parse_dates=['Date'])

# %%
data.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume              float64
# dtype: object

# %% [markdown]
# If we now set the Date column to be the index, we effectively create our first Time Series

# %%
data.set_index('Date', inplace=True)

# %% [markdown]
# We see that pandas automatically generated a "DatetimeIndex" object that allos us to take advantage of the fact that we are dealing with dates

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 9887 entries, 1980-12-12 to 2020-02-28
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       9886 non-null   float64
#  1   High       9886 non-null   float64
#  2   Low        9886 non-null   float64
#  3   Close      9886 non-null   float64
#  4   Adj Close  9886 non-null   float64
#  5   Volume     9886 non-null   float64
# dtypes: float64(6)
# memory usage: 540.7 KB

# %% [markdown]
# We can easily access parts of the date object

# %%
data
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1980-12-12    0.513393    0.515625    0.513393    0.513393    0.406782
# 1980-12-15    0.488839    0.488839    0.486607    0.486607    0.385558
# 1980-12-16    0.453125    0.453125    0.450893    0.450893    0.357260
# 1980-12-17    0.462054    0.464286    0.462054    0.462054    0.366103
# 1980-12-18    0.475446    0.477679    0.475446    0.475446    0.376715
# ...                ...         ...         ...         ...         ...
# 2020-02-24  297.260010  304.179993  289.230011  298.179993  298.179993
# 2020-02-25  300.950012  302.529999  286.130005  288.079987  288.079987
# 2020-02-26  286.529999  297.880005  286.500000  292.649994  292.649994
# 2020-02-27  281.100006  286.000000  272.959991  273.519989  273.519989
# 2020-02-28  257.260010  278.410004  256.369995  273.359985  273.359985
#
#                  Volume
# Date
# 1980-12-12  117258400.0
# 1980-12-15   43971200.0
# 1980-12-16   26432000.0
# 1980-12-17   21610400.0
# 1980-12-18   18362400.0
# ...                 ...
# 2020-02-24   55548800.0
# 2020-02-25   57668400.0
# 2020-02-26   49513700.0
# 2020-02-27   80151400.0
# 2020-02-28  106627500.0
#
# [9887 rows x 6 columns]

# %%
data.index.month
# Out:
# Int64Index([12, 12, 12, 12, 12, 12, 12, 12, 12, 12,
#             ...
#              2,  2,  2,  2,  2,  2,  2,  2,  2,  2],
#            dtype='int64', name='Date', length=9887)

# %%
data.index.year
# Out:
# Int64Index([1980, 1980, 1980, 1980, 1980, 1980, 1980, 1980, 1980, 1980,
#             ...
#             2020, 2020, 2020, 2020, 2020, 2020, 2020, 2020, 2020, 2020],
#            dtype='int64', name='Date', length=9887)

# %%
data.index.day
# Out:
# Int64Index([12, 15, 16, 17, 18, 19, 22, 23, 24, 26,
#             ...
#             14, 18, 19, 20, 21, 24, 25, 26, 27, 28],
#            dtype='int64', name='Date', length=9887)

# %% [markdown]
# And slice the DataFrame by date

# %%
data.loc['2010':'2010-06-10'].round(2)
# Out:
#              Open   High    Low  Close  Adj Close       Volume
# Date
# 2010-01-04  30.49  30.64  30.34  30.57      26.54  123432400.0
# 2010-01-05  30.66  30.80  30.46  30.63      26.58  150476200.0
# 2010-01-06  30.63  30.75  30.11  30.14      26.16  138040000.0
# 2010-01-07  30.25  30.29  29.86  30.08      26.11  119282800.0
# 2010-01-08  30.04  30.29  29.87  30.28      26.29  111902700.0
# ...           ...    ...    ...    ...        ...          ...
# 2010-06-04  36.89  37.41  36.38  36.57      31.74  189576100.0
# 2010-06-07  36.90  37.02  35.79  35.85      31.12  221735500.0
# 2010-06-08  36.18  36.26  35.09  35.62      30.92  250192600.0
# 2010-06-09  35.92  35.99  34.64  34.74      30.16  213657500.0
# 2010-06-10  34.98  35.85  34.60  35.79      31.06  194089000.0
#
# [110 rows x 6 columns]

# %% [markdown]
# As before, we note that the last value is also included

# %% [markdown]
# ## DataFrame Manipulations

# %% [markdown]
# Map allows us to easily apply a function to the rows of a Series.

# %%
movies['Director'].head()
# Out:
# Title
# Intolerance: Love's Struggle Throughout the Ages           D.W. Griffith
# Over the Hill to the Poorhouse                         Harry F. Millarde
# The Big Parade                                                King Vidor
# Metropolis                                                    Fritz Lang
# Pandora's Box                                        Georg Wilhelm Pabst
# Name: Director, dtype: object

# %%
movies['Director'].map(lambda x: x.lower())
# Out:
# Title
# Intolerance: Love's Struggle Throughout the Ages           d.w. griffith
# Over the Hill to the Poorhouse                         harry f. millarde
# The Big Parade                                                king vidor
# Metropolis                                                    fritz lang
# Pandora's Box                                        georg wilhelm pabst
#                                                             ...
# Twin Falls Idaho                                          michael polish
# Universal Soldier: The Return                                mic rodgers
# Varsity Blues                                              brian robbins
# Wild Wild West                                          barry sonnenfeld
# Wing Commander                                             chris roberts
# Name: Director, Length: 1338, dtype: object

# %% [markdown]
# For a dataframe we need to use transform

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1338 entries, Intolerance: Love's Struggle Throughout the Ages  to Wing Commander
# Data columns (total 25 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Year                         1338 non-null   int64
#  1   Genres                       1338 non-null   object
#  2   Language                     1334 non-null   object
#  3   Country                      1338 non-null   object
#  4   Content Rating               1316 non-null   object
#  5   Duration                     1338 non-null   int64
#  6   Aspect Ratio                 1308 non-null   float64
#  7   Budget                       1281 non-null   float64
#  8   Gross Earnings               1086 non-null   float64
#  9   Director                     1338 non-null   object
#  10  Actor 1                      1338 non-null   object
#  11  Actor 2                      1338 non-null   object
#  12  Actor 3                      1336 non-null   object
#  13  Facebook Likes - Director    1338 non-null   int64
#  14  Facebook Likes - Actor 1     1338 non-null   int64
#  15  Facebook Likes - Actor 2     1338 non-null   int64
#  16  Facebook Likes - Actor 3     1336 non-null   float64
#  17  Facebook Likes - cast Total  1338 non-null   int64
#  18  Facebook likes - Movie       1338 non-null   int64
#  19  Facenumber in posters        1338 non-null   int64
#  20  User Votes                   1338 non-null   int64
#  21  Reviews by Users             1338 non-null   int64
#  22  Reviews by Crtiics           1335 non-null   float64
#  23  IMDB Score                   1338 non-null   float64
#  24  Budget2                      1281 non-null   float64
# dtypes: float64(7), int64(10), object(8)
# memory usage: 311.8+ KB

# %%
movies[['Duration', 'Budget']].transform(lambda x: x * 2)
# Out:
#                                                    Duration       Budget
# Title
# Intolerance: Love's Struggle Throughout the Ages        246     771814.0
# Over the Hill to the Poorhouse                          220     200000.0
# The Big Parade                                          302     490000.0
# Metropolis                                              290   12000000.0
# Pandora's Box                                           220          NaN
# ...                                                     ...          ...
# Twin Falls Idaho                                        222    1000000.0
# Universal Soldier: The Return                           166   48000000.0
# Varsity Blues                                           212   32000000.0
# Wild Wild West                                          212  340000000.0
# Wing Commander                                          200   60000000.0
#
# [1338 rows x 2 columns]

# %% [markdown]
# Or apply

# %%
movies[['Duration', 'Budget']].apply(np.sum, axis=0)
# Out:
# Duration    1.512890e+05
# Budget      3.474154e+10
# dtype: float64

# %%
movies[['Duration', 'Budget']].apply(np.sum, axis=1)
# Out:
# Title
# Intolerance: Love's Struggle Throughout the Ages        386030.0
# Over the Hill to the Poorhouse                          100110.0
# The Big Parade                                          245151.0
# Metropolis                                             6000145.0
# Pandora's Box                                              110.0
#                                                         ...
# Twin Falls Idaho                                        500111.0
# Universal Soldier: The Return                         24000083.0
# Varsity Blues                                         16000106.0
# Wild Wild West                                       170000106.0
# Wing Commander                                        30000100.0
# Length: 1338, dtype: float64

# %% [markdown]
# ## Merge and Join

# %% [markdown]
# Define 2 toy DataFrames

# %%
A = pd.DataFrame({"lkey":["foo", "bar", "baz", "foo"], "value":[1,2,3,4]})
B = pd.DataFrame({"rkey":["foo", "bar", "qux", "bar"], "value":[5,6,7,8]})

# %% [markdown]
# Merge allows us to join them by specifying an arbitrary column on each of them

# %%
A.merge(B, left_on="lkey", right_on="rkey", how="left")
# Out:
#   lkey  value_x rkey  value_y
# 0  foo        1  foo        5
# 1  foo        4  foo        5
# 2  bar        2  bar        6
# 3  bar        2  bar        8

# %% [markdown]
# On the other hand, join performs the join using the respective Indices

# %%
A.set_index('lkey', inplace=True)
B.set_index('rkey', inplace=True)

# %%
A.join(B, lsuffix="_l", rsuffix="_r", how="inner")
# Out:
#      value_l  value_r
# bar        2        6
# bar        2        8
# foo        1        5
# foo        4        5

# %% [markdown]
# <div style="width: 100%; overflow: hidden;">
#      <img src="data/D4Sci_logo_full.png" alt="Data For Science, Inc" align="center" border="0" width=300px>
# </div>
